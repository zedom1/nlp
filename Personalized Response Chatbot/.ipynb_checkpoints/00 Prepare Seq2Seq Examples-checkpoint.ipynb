# %%
import re
import codecs

# %%
txt = codecs.open('./data/seq2seq/sentences.txt',"r","utf-8").read()

# %%
exec(open("preppy.py").read())

# %%
split_reg = re.compile('\n')

# %% [markdown]
# # parse the raw text of QA into dictionary

# %%
sentences = split_reg.split(txt)

# %%
print(sentences[0])
# Out:
# 这 让 我 怎么 相信 爱情 诶

# %% [markdown]
# One single line demo

# %%
verses_splitter = re.compile('(?P<sentence>.+)',)

# %%
gen = verses_splitter.finditer(sentences[0].replace("\n",""))

# %%
next(gen).groupdict()
# Out:
# {'sentence': '这 让 我 怎么 相信 爱情 诶\r'}

# %% [markdown]
# Lets run all of that on the entire text

# %%
examples= []
for line in sentences:
    for verse_regex_match in verses_splitter.finditer(line):
        example = verse_regex_match.groupdict()
        example.update({"sentence":example["sentence"].strip()})
        examples.append(example)

# %%
len(examples)
print((examples[0]))
# Out:
# {'sentence': '这 让 我 怎么 相信 爱情 诶'}

# %%
import pickle
pickle.dump(examples,open('./data/seq2seq/examples.pkl','wb'))

# %% [markdown]
# # Now we make them into TF records

# %%
import tensorflow as tf
from preppy import Preppy
import numpy as np

# %%
import random
random.shuffle(examples)
val_size = int(len(examples)*0.25)
val,train = examples[:val_size], examples[val_size:]

# %%
def tokenizer(sentence):
    return sentence.split()
    
BP =Preppy(tokenizer_fn=tokenizer) #Charecter level tokenization
BP.init_vocab()

for example in examples:
    BP.prepare_vocab(sequence=example["sentence"])
    
BP.vocab_filter()

for (data,path) in [(val,'./data/seq2seq/val.tfrecord'),(train,'./data/seq2seq/train.tfrecord')]:
    with open(path,'w') as f:
        writer = tf.python_io.TFRecordWriter(f.name)
    for example in data:
        record = BP.sequence_to_tf_example(sequence=example["sentence"])
        writer.write(record.SerializeToString())

# %%
BP.update_reverse_vocab()

# %%
pickle.dump(BP,open('./data/seq2seq/preppy.pkl','wb'))

# %%
len(BP.vocab)
# Out:
# 5728

# %%
BP.vocab["<START>"]
# Out:
# 1

# %%
BP.vocab
# Out:
# defaultdict(<bound method Preppy.next_value of <preppy.Preppy object at 0x000002100FF36F28>>,
#             {'<PAD>': 0,
#              '<START>': 1,
#              '<EOS>': 2,
#              '<UNK>': 3,
#              '恩': 4,
#              '本科': 5,
#              '英语': 6,
#              '专': 7,
#              '八': 8,
#              '我': 9,
#              '也': 10,
#              '已经': 11,
#              '是': 12,
#              '二面': 13,
#              '了不': 14,
#              '过': 15,
#              '后来': 16,
#              '又': 17,
#              '来': 18,
#              '了': 19,
#              '一个': 20,
#              '很': 21,
#              '的': 23,
#              '女人': 24,
#              '给': 25,
#              '面试': 26,
#              '好像': 27,
#              '她们': 28,
#              '那': 30,
#              '程序': 32,
#              '问': 33,
#              '她': 34,
#              '这': 35,
#              '第': 36,
#              '几': 37,
#              '轮': 38,
# ...

# %%
BP.token_counter
# Out:
# Counter({'恩': 110,
#          '本科': 9,
#          '英语': 38,
#          '专': 8,
#          '八': 29,
#          '我': 6770,
#          '也': 1563,
#          '已经': 250,
#          '是': 2893,
#          '二面': 3,
#          '了不': 95,
#          '过': 591,
#          '后来': 79,
#          '又': 284,
#          '来': 459,
#          '了': 4618,
#          '一个': 572,
#          '很': 963,
#          '的': 8950,
#          '女人': 72,
#          '给': 485,
#          '面试': 27,
#          '好像': 115,
#          '她们': 26,
#          '那': 831,
#          '程序': 5,
#          '问': 180,
#          '她': 422,
#          '这': 779,
#          '第': 93,
#          '几': 139,
#          '轮': 4,
#          '啊': 1915,
#          '女': 119,
#          '表现': 33,
#          '什么意思': 5,
#          '有点': 155,
#          '吓': 24,
#          '到': 441,
#          '脚': 28,
#          '抖': 5,
#          '嘛': 229,
#          '告诉': 111,
#          '不是': 561,
#          '想': 625,
#          '多': 519,
#          '其实': 323,
# ...

# %%
voca_file = open("./data/voca.pkl","wb")
pickle.dump(BP.vocab, voca_file)
voca_file.close()
