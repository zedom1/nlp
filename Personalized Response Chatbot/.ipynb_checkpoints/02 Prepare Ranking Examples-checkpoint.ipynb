# %%
import re
import codecs

# %%
txt = codecs.open('./data/demo_user.txt',"r","utf-8").read()

# %%
exec(open("preppy.py").read())

# %%
split_reg = re.compile('\r\n')

# %% [markdown]
# # parse the raw text of QA into dictionary

# %%
books = split_reg.split(txt)

# %%
print(books[0])
# Out:
# 11	0	那 我 也是 曾经 的 情人 啊 最 伤 自尊 的 是 他 姐姐 说 她 看到 我 时 一度 质疑 我 ex 的 审美 不过 那 时候 我 还是 高中生	耐心 的 双鱼 还好 点 但是 八 竿子 打 不 出来 一句话 那 就 悲剧 了

# %% [markdown]
# One single line demo

# %%
verses_splitter = re.compile('(?P<user>\d+)\t(?P<label>\d+)\t(?P<query>.+?)\t(?P<response>.+)',)

# %%
gen = verses_splitter.finditer(books[0].replace("\n",""))

# %%
next(gen).groupdict()
# Out:
# {'user': '11',
#  'label': '0',
#  'query': '那 我 也是 曾经 的 情人 啊 最 伤 自尊 的 是 他 姐姐 说 她 看到 我 时 一度 质疑 我 ex 的 审美 不过 那 时候 我 还是 高中生',
#  'response': '耐心 的 双鱼 还好 点 但是 八 竿子 打 不 出来 一句话 那 就 悲剧 了'}

# %% [markdown]
# Lets run all of that on the entire text

# %%
examples= []
for line in books:
    for verse_regex_match in verses_splitter.finditer(line):
        example = verse_regex_match.groupdict()
        example.update({"user":example["user"],"label":example["label"],"query":example["query"].strip(),"response":example["response"].strip()})
        examples.append(example)

# %%
len(examples)
print((examples[0]))
# Out:
# {'user': '11', 'label': '0', 'query': '那 我 也是 曾经 的 情人 啊 最 伤 自尊 的 是 他 姐姐 说 她 看到 我 时 一度 质疑 我 ex 的 审美 不过 那 时候 我 还是 高中生', 'response': '耐心 的 双鱼 还好 点 但是 八 竿子 打 不 出来 一句话 那 就 悲剧 了'}

# %%
import pickle
pickle.dump(examples,open('./data/demo_data.pkl','wb'))

# %% [markdown]
# # Now we make them into TF records

# %%
import tensorflow as tf
from preppy import MyPreppy
import numpy as np

# %%
import random
random.shuffle(examples)
val_size = int(len(examples)*0.25)
val,train = examples[:val_size], examples[val_size:]

# %%
def tokenizer(sentence):
    return sentence.split()
    
BP =MyPreppy(tokenizer_fn=tokenizer) #Charecter level tokenization
for (data,path) in [(val,'./data/val.tfrecord'),(train,'./data/train.tfrecord')]:
    with open(path,'w') as f:
        writer = tf.python_io.TFRecordWriter(f.name)
    for example in data:
        record = BP.sequence_to_tf_example(sequence_q=example["query"],
                                           sequence_a=example["response"],
                                           label=int(example["label"]),
                                           user = int(example["user"]))
        writer.write(record.SerializeToString())

# %%
BP.update_reverse_vocab()

# %%
pickle.dump(BP,open('./data/preppy.pkl','wb'))

# %%
len(BP.vocab)
# Out:
# 17038

# %%
BP.vocab["<START>"]
# Out:
# 1

# %%
BP.vocab
# Out:
# defaultdict(<bound method Preppy.next_value of <preppy.MyPreppy object at 0x0000020AACA70F28>>,
#             {'<PAD>': 0,
#              '<START>': 1,
#              '<EOS>': 2,
#              '我': 3,
#              '豆': 4,
#              '邮': 5,
#              '给': 6,
#              '你': 7,
#              '哈': 8,
#              '丫': 9,
#              '还': 10,
#              '删': 11,
#              '回复': 12,
#              '174': 13,
#              '175': 14,
#              '谁': 15,
#              '能': 16,
#              '看得': 17,
#              '出来': 18,
#              '那么': 19,
#              '点': 20,
#              '的': 21,
#              '差距': 22,
#              '不': 23,
#              '花心': 24,
#              '就': 25,
#              '好': 26,
#              '咱们': 27,
#              '搅基': 28,
#              '吧': 29,
#              '在': 30,
#              '自言自语': 31,
#              '嘛': 32,
#              '哈哈': 33,
#              '童靴': 34,
#              '甘': 35,
#              '跑': 36,
#              '特特': 37,
#              '像': 38,
#              '这': 39,
#              '花儿一样': 40,
#              '妹子': 41,
#              '应该': 42,
#              '是': 43,
#              '用': 44,
#              '蜜水': 45,
#              '养成': 46,
#              '倒是': 47,
#              '没': 48,
#              '准': 49,
#              '打': 50,
#              '会': 51,
#              '台球': 52,
#              '去': 53,
#              '看': 54,
#              '电脑': 55,
#              '时间': 56,
#              '长': 57,
#              '了': 58,
#              '爱': 59,
#              '脑袋': 60,
#              '疼': 61,
#              '笔记本': 62,
#              '手机': 63,
#              '查': 64,
#              '啊': 65,
#              '或者': 66,
#              '12580': 67,
#              '木': 68,
#              '有爱': 69,
#              '疯': 70,
#              '弄': 71,
#              '鸡鸭': 72,
#              '口': 73,
#              '以': 74,
#              '吗': 75,
#              '不会': 76,
#              '反正': 77,
#              '了一': 78,
#              '公分': 79,
#              '只要': 80,
#              '和': 81,
#              '自己': 82,
#              '其他': 83,
#              '部位': 84,
#              '比': 85,
#              '行': 86,
#              '每个': 87,
#              '人': 88,
#              '身体': 89,
#              '比例': 90,
#              '不一样': 91,
#              '没有': 92,
#              '可比性': 93,
#              '姑娘': 94,
#              '看着': 95,
#              '不是': 96,
#              '这个': 97,
#              '生活': 98,
#              '中的': 99,
#              '强尼': 100,
#              '德普': 101,
#              '对': 102,
#              '薇诺娜瑞德': 103,
#              '说': 104,
#              '胡子': 105,
#              '脸型': 106,
#              '比较': 107,
#              '私下': 108,
#              '告诉': 109,
#              '多少': 110,
#              '加油': 111,
#              '106': 112,
#              '节食': 113,
#              '158': 114,
#              '面包': 115,
#              '有': 116,
#              '真爱': 117,
#              '恩': 118,
#              '楼主': 119,
#              '朵': 120,
#              '内心强大': 121,
#              '女': 122,
#              '纸': 123,
#              '也不是': 124,
#              '看到': 125,
#              '之后': 126,
#              '感情': 127,
#              '很': 128,
#              '复杂': 129,
#              '撇开': 130,
#              '别的': 131,
#              '因素': 132,
#              '来': 133,
#              '真的': 134,
#              '挺': 135,
#              '美': 136,
#              '笑': 137,
#              '起来': 138,
#              '漂亮': 139,
#              '试试': 140,
#              '知道': 141,
#              '放': 142,
#              '在哪里': 143,
#              '都': 144,
#              '所以': 145,
#              '才': 146,
#              '要': 147,
#              '问': 148,
#              '怎样': 149,
#              '算': 150,
#              '最': 151,
#              '舒服': 152,
#              '没关系': 153,
#              '随便': 154,
#              '看看': 155,
#              '呗': 156,
#              '指点': 157,
#              '虚心': 158,
#              '接受': 159,
#              '亲': 160,
#              '已经': 161,
#              '光光': 162,
#              '然后': 163,
#              '呢': 164,
#              '大师': 165,
#              '儿子': 166,
#              '喜欢': 167,
#              '喝': 168,
#              '洗脚': 169,
#              '水': 170,
#              '囧': 171,
#              '确定': 172,
#              '它': 173,
#              '没事': 174,
#              '实体店': 175,
#              '贵': 176,
#              '也': 177,
#              '想': 178,
#              '网购': 179,
#              '关键': 180,
#              '担心': 181,
#              '遇到': 182,
#              '反复': 183,
#              '死机': 184,
#              '那种': 185,
#              '突然': 186,
#              '抖': 187,
#              '一下': 188,
#              '可以': 189,
#              '咩': 190,
#              '星星': 191,
#              '眼': 192,
#              '介个': 193,
#              '价格': 194,
#              '还要': 195,
#              '砍': 196,
#              '么': 197,
#              '专柜': 198,
#              '6': 199,
#              '折': 200,
#              '不到': 201,
#              '包': 202,
#              '江浙': 203,
#              '沪': 204,
#              '下': 205,
#              'tb': 206,
#              '五百': 207,
#              '多': 208,
#              '四百': 209,
#              '不少': 210,
#              '两百': 211,
#              '正': 212,
#              '真心': 213,
#              '觉得': 214,
#              '不算': 215,
#              'orz': 216,
#              '那': 217,
#              '得': 218,
#              '地方': 219,
#              '虽说': 220,
#              '这种': 221,
#              '情况': 222,
#              '但是': 223,
#              '当地': 224,
#              '工作': 225,
#              '人员': 226,
#              '靠': 227,
#              '这些': 228,
#              '收': 229,
#              '养活': 230,
#              '其实': 231,
#              '仁者见仁': 232,
#              '智者': 233,
#              '见': 234,
#              '智': 235,
#              '感谢': 236,
#              '科普': 237,
#              '好想': 238,
#              '张': 239,
#              '照片': 240,
#              'hsu': 241,
#              '许维恩': 242,
#              '怎么': 243,
#              '解释': 244,
#              '太': 245,
#              '艰难': 246,
#              '只有': 247,
#              '强大': 248,
#              '才能': 249,
#              '走': 250,
#              '完': 251,
#              '条': 252,
#              '路': 253,
#              '了解': 254,
#              '做': 255,
#              '销售': 256,
#              '就算': 257,
#              '一个': 258,
#              '正直': 259,
#              '进': 260,
#              '都会': 261,
#              '耳濡目染': 262,
#              '变成': 263,
#              '家里': 264,
#              '之前': 265,
#              '开': 266,
#              '公司': 267,
#              '家人': 268,
#              '过': 269,
#              '员工': 270,
#              '呵': 271,
#              '呵呵': 272,
#              '男朋友': 273,
#              '当初': 274,
#              '换': 275,
#              '考虑': 276,
#              '分手': 277,
#              '要是': 278,
#              '小伙子': 279,
#              '话': 280,
#              '早点': 281,
#              '分': 282,
#              '呀': 283,
#              '冰砖': 284,
#              '菇凉': 285,
#              '薄': 286,
#              '今天': 287,
#              '又': 288,
#              '买': 289,
#              '伤感': 290,
#              '如释重负': 291,
#              '扣子': 292,
#              '开来': 293,
#              '别': 294,
#              '找': 295,
#              '这里': 296,
#              '认识': 297,
#              '几个': 298,
#              '朋友': 299,
#              '还是': 300,
#              '讲讲': 301,
#              '以前': 302,
#              '咯': 303,
#              '07': 304,
#              '年': 305,
#              '送': 306,
#              '带': 307,
#              '小': 308,
#              '根': 309,
#              '绿萝': 310,
#              '叶子': 311,
#              '本人': 312,
#              '水培': 313,
#              '选': 314,
#              '中间': 315,
#              '根须': 316,
#              '这样': 317,
#              '里': 318,
#              '快': 319,
#              '那个': 320,
#              '小小': 321,
#              '瓶子': 322,
#              '着': 323,
#              '泡': 324,
#              '个': 325,
#              '一': 326,
#              '星期': 327,
#              '出': 328,
#              '新': 329,
#              '基本上': 330,
#              '少': 331,
#              '加': 332,
#              '留': 333,
#              '原来': 334,
#              '基本': 335,
#              '时候': 336,
#              '忘记': 337,
#              '半个': 338,
#              '月': 339,
#              '也是': 340,
#              '出现': 341,
#              '跟': 342,
#              '两年': 343,
#              '再': 344,
#              '后来': 345,
#              '搬': 346,
#              '回': 347,
#              '广东': 348,
#              '跟着': 349,
#              '大概': 350,
#              '就是': 351,
#              '这么': 352,
#              '不用': 353,
#              '费心': 354,
#              '养': 355,
#              '现在': 356,
#              '广州': 357,
#              '不过': 358,
#              '这次': 359,
#              '土': 360,
#              '花盆': 361,
#              '下面': 362,
#              '盆': 363,
#              '两': 364,
#              '到': 365,
#              '三': 366,
#              '天': 367,
#              '往': 368,
#              '注水': 369,
#              '一次': 370,
#              '面': 371,
#              '上': 372,
#              '喷': 373,
#              '点水': 374,
#              '上班': 375,
#              '前': 376,
#              '把': 377,
#              '太阳': 378,
#              '晒': 379,
#              '阳光': 380,
#              '弱': 381,
#              '回家': 382,
#              '搬进': 383,
#              '目前': 384,
#              '哦哦': 385,
#              '马上': 386,
#              '谢谢': 387,
#              '啦': 388,
#              '嘻嘻': 389,
#              '托': 390,
#              '吉言': 391,
#              '爱情': 392,
#              '不经意': 393,
#              '间': 394,
#              '来到': 395,
#              '直白': 396,
#              '些': 397,
#              '让': 398,
#              '更': 399,
#              '清醒': 400,
#              '早': 401,
#              '2': 402,
#              '小时': 403,
#              '快来': 404,
#              '有人': 405,
#              '为什么': 406,
#              '女人': 407,
#              '受伤': 408,
#              '逻辑': 409,
#              '诡谲': 410,
#              '完全': 411,
#              '他': 412,
#              '套': 413,
#              '硬': 414,
#              '加紧': 415,
#              '双腿': 416,
#              '保护': 417,
#              '甚至': 418,
#              '干脆': 419,
#              '甩': 420,
#              '可怜之人必有可恨之处': 421,
#              '立场': 422,
#              '弱者': 423,
#              '满意': 424,
#              '噢': 425,
#              '在意': 426,
#              '可能': 427,
#              '五一': 428,
#              '玩': 429,
#              '讨好': 430,
#              '他他': 431,
#              '开心': 432,
#              '坏': 433,
#              '毛病': 434,
#              '主动': 435,
#              '联系': 436,
#              '发': 437,
#              '信息': 438,
#              '真是': 439,
#              '秒钟': 440,
#              '总': 441,
#              '意气用事': 442,
#              '不知道': 443,
#              '怎么办': 444,
#              '呼呼': 445,
#              '我们': 446,
#              '俩': 447,
#              '第': 448,
#              '二': 449,
#              '阶段': 450,
#              '到了': 451,
#              '理': 452,
#              '大事': 453,
#              '只是': 454,
#              '希望': 455,
#              '考研': 456,
#              '顺利': 457,
#              '昨晚': 458,
#              '虐': 459,
#              '淡定': 460,
#              '摩羯': 461,
#              '都是': 462,
#              '互': 463,
#              '中': 464,
#              '升华': 465,
#              'mm': 466,
#              '坚持': 467,
#              '多久': 468,
#              '接触': 469,
#              '过后': 470,
#              '星座': 471,
#              '男': 472,
#              '恐怕': 473,
#              '不在话下': 474,
#              '祝': 475,
#              '好运': 476,
#              '佛教': 477,
#              '之中': 478,
#              '音乐': 479,
#              '经典': 480,
#              '每': 481,
#              '感到': 482,
#              '负面': 483,
#              '能量': 484,
#              '地': 485,
#              '藏经': 486,
#              '心经': 487,
#              '问题': 488,
#              '段': 489,
#              '每天': 490,
#              '诵读': 491,
#              '老是': 492,
#              '一种': 493,
#              '被': 494,
#              '抽空': 495,
#              '感觉': 496,
#              '葱': 497,
#              '蒜': 498,
#              '吃': 499,
#              '入教': 500,
#              '信仰': 501,
#              '信': 502,
#              '基督': 503,
#              '一本': 504,
#              '圣经': 505,
#              '曾经': 506,
#              '苦恼': 507,
#              '病痛': 508,
#              '折磨': 509,
#              '默读': 510,
#              '里面': 511,
#              '诗篇': 512,
#              '耶和华': 513,
#              '心底': 514,
#              '支柱': 515,
#              '不要紧': 516,
#              '主要': 517,
#              '放下': 518,
#              '桑': 519,
#              '心': 520,
#              '处': 521,
#              '错误': 522,
#              '打算': 523,
#              '今年': 524,
#              '领证': 525,
#              '明年': 526,
#              '办': 527,
#              '婚礼': 528,
#              '方法': 529,
#              '不靠谱': 530,
#              '对于': 531,
#              '女孩子': 532,
#              '风险': 533,
#              '字体': 534,
#              '尽量': 535,
#              '不要': 536,
#              '改': 537,
#              '生产': 538,
#              'pdf': 539,
#              '麻烦': 540,
#              '枪迷': 541,
#              '邯郸学步': 542,
#              '邯郸': 543,
#              '·': 544,
#              '难得': 545,
#              '老乡': 546,
#              '诶': 547,
#              '黑': 548,
#              '嗯嗯': 549,
#              '坚决': 550,
#              '不客气': 551,
#              '旁观': 552,
#              '帮': 553,
#              '别人': 554,
#              '是不是': 555,
#              '男人': 556,
#              '重要': 557,
#              '过去了': 558,
#              '是什么': 559,
#              '样': 560,
#              '世界': 561,
#              '除了': 562,
#              '享受': 563,
#              '但': 564,
#              '绝不': 565,
#              '放纵': 566,
#              '吐槽': 567,
#              '杠杠': 568,
#              '不稀得': 569,
#              '一一': 570,
#              '列举': 571,
#              '可爱': 572,
#              '耐心': 573,
#              'y': 574,
#              '回来': 575,
#              '稳': 576,
#              '前面': 577,
#              '门': 578,
#              '等': 579,
#              '走上': 580,
#              '离': 581,
#              '至少': 582,
#              '十': 583,
#              '几米': 584,
#              '远': 585,
#              '一直': 586,
#              '扶': 587,
#              '只不过': 588,
#              '酒': 589,
#              '又不是': 590,
#              '神志': 591,
#              '清': 592,
#              '什么': 593,
#              '每次': 594,
#              '发飙': 595,
#              '实话': 596,
#              '一点': 597,
#              '期望': 598,
#              '多大': 599,
#              '停止': 600,
#              '确实': 601,
#              '╮': 602,
#              '¯': 603,
#              '▽': 604,
#              '╭': 605,
#              '呸': 606,
#              '犀利': 607,
#              '读法': 608,
#              '三围': 609,
#              '解读': 610,
#              '无': 611,
#              '每年': 612,
#              '同学': 613,
#              '花': 614,
#              '好几': 615,
#              '百万': 616,
#              '矮油': 617,
#              '发现': 618,
#              '顿悟': 619,
#              '地鼠': 620,
#              '简易': 621,
#              '梅花': 622,
#              '偷偷': 623,
#              '豆油': 624,
#              '原因': 625,
#              '承认': 626,
#              '默契': 627,
#              '很好': 628,
#              '培养': 629,
#              '嗯': 630,
#              '狮子': 631,
#              '同类': 632,
#              '心里': 633,
#              '住': 634,
#              '孩子': 635,
#              '越': 636,
#              '小孩': 637,
#              '帖子': 638,
#              '去年': 639,
#              'lz': 640,
#              '找到': 641,
#              '一起': 642,
#              '成功': 643,
#              '撞墙': 644,
#              '撞': 645,
#              '一会': 646,
#              '链接': 647,
#              '大嘴猴': 648,
#              '红色': 649,
#              '要件': 650,
#              '简单': 651,
#              '白': 652,
#              '袖': 653,
#              '还有': 654,
#              '市镇': 655,
#              '孙子': 656,
#              '巧克力': 657,
#              '一段': 658,
#              '地址': 659,
#              '已': 660,
#              '终于': 661,
#              '应征': 662,
#              '欢迎': 663,
#              '入': 664,
#              '征': 665,
#              '明确': 666,
#              '表态': 667,
#              '转': 668,
#              '成': 669,
#              'word': 670,
#              '部分': 671,
#              '从': 672,
#              'txt': 673,
#              'mobi': 674,
#              '文档': 675,
#              '稍稍': 676,
#              '排版': 677,
#              '因为': 678,
#              '段落格式': 679,
#              '与': 680,
#              '脚注': 681,
#              '全': 682,
#              '乱': 683,
#              '段落': 684,
#              '编辑': 685,
#              '注脚': 686,
#              '难以': 687,
#              '准备': 688,
#              '定位': 689,
#              '小动作': 690,
#              '各种': 691,
#              '萌': 692,
#              '好看': 693,
#              '型': 694,
#              '做作': 695,
#              '伦家': 696,
#              '东北': 697,
#              '干嘛': 698,
#              '叫': 699,
#              '黄脸婆': 700,
#              '是的': 701,
#              '憧憬': 702,
#              '商人': 703,
#              '强人': 704,
#              '根据': 705,
#              '量表': 706,
#              '真': 707,
#              '不适合': 708,
#              '愿意': 709,
#              '相信': 710,
#              '现实': 711,
#              '条件': 712,
#              '机遇': 713,
#              '同样': 714,
#              '影响': 715,
#              '命运': 716,
#              '性格': 717,
#              '决定': 718,
#              '虽然': 719,
#              '出去': 720,
#              '微信': 721,
#              '聊': 722,
#              '哇塞': 723,
#              '素': 724,
#              '传说': 725,
#              '好像': 726,
#              '知己': 727,
#              '崇高': 728,
#              '超越': 729,
#              '盆友': 730,
#              '算是': 731,
#              '妞儿': 732,
#              '兴趣': 733,
#              '过来': 734,
#              '叙': 735,
#              '早就': 736,
#              '关': 737,
#              '掉': 738,
#              'tt': 739,
#              '班级': 740,
#              '聚会': 741,
#              '大清谷': 742,
#              '社团': 743,
#              '预算': 744,
#              '稍微': 745,
#              '充足': 746,
#              '一些': 747,
#              '亲身': 748,
#              '为': 749,
#              '五十': 750,
#              '块': 751,
#              '钱': 752,
#              '干': 753,
#              '爸妈': 754,
#              '起': 755,
#              '可': 756,
#              '哎': 757,
#              'man': 758,
#              'boobs': 759,
#              '受不了': 760,
#              '好不': 761,
#              '容易': 762,
#              '练': 763,
#              '简直': 764,
#              '驼背': 765,
#              '噩梦': 766,
#              '罪魁祸首': 767,
#              '很好奇': 768,
#              '功夫': 769,
#              '3': 770,
#              '号': 771,
#              'club21': 772,
#              '旗下': 773,
#              '新加坡': 774,
#              '常在': 775,
#              '如果': 776,
#              '酒店': 777,
#              '能干': 778,
#              '粗': 779,
#              '多谢': 780,
#              '鸡翅': 781,
#              '哥': 782,
#              '交': 783,
#              'friend': 784,
#              'v': 785,
#              '瞬间': 786,
#              '懂': 787,
#              '手艺': 788,
#              '摇': 789,
#              'hold': 790,
#              '秒': 791,
#              '拿': 792,
#              '水晶': 793,
#              '找不到': 794,
#              '算命': 795,
#              '知道么': 796,
#              '怪不得': 797,
#              '屠': 798,
#              '洪': 799,
#              '纲': 800,
#              '受': 801,
#              '李晨': 802,
#              '演员': 803,
#              'vj': 804,
#              'gay': 805,
#              '不在': 806,
#              'qq': 807,
#              '赤裸裸': 808,
#              '打击': 809,
#              '广州市': 810,
#              '芳村': 811,
#              '岭南': 812,
#              '花市': 813,
#              '南区': 814,
#              '大棚': 815,
#              '位': 816,
#              '他们': 817,
#              '网站': 818,
#              'url': 819,
#              '绿色': 820,
#              '肉肉': 821,
#              '蓝色': 822,
#              '紫色': 823,
#              '之类': 824,
#              '内': 825,
#              '18': 826,
#              '人物': 827,
#              '流汗': 828,
#              '可是': 829,
#              '厨子': 830,
#              '随意': 831,
#              '感慨': 832,
#              '一句': 833,
#              '纠结': 834,
#              '装': 835,
#              '啥': 836,
#              '大丫头': 837,
#              '堵': 838,
#              'ex': 839,
#              '体会': 840,
#              '恩好': 841,
#              '冯德伦': 842,
#              '中长发': 843,
#              '美日': 844,
#              '霸气': 845,
#              '温柔': 846,
#              'nce': 847,
#              '了不': 848,
#              '保险': 849,
#              '不能': 850,
#              '男神': 851,
#              '犯': 852,
#              '懒': 853,
#              '玩玩': 854,
#              '本来': 855,
#              '属于': 856,
#              '快乐': 857,
#              'oo': 858,
#              '睡觉': 859,
#              '晚安': 860,
#              '吻': 861,
#              '圆满': 862,
#              '乐意': 863,
#              '浪费': 864,
#              '嘿嘿': 865,
#              '当': 866,
#              '妈': 867,
#              '替': 868,
#              '收拾': 869,
#              '烂摊子': 870,
#              '够': 871,
#              '详细': 872,
#              '3q': 873,
#              '大盘鸡': 874,
#              '西街': 875,
#              '新疆': 876,
#              '餐馆': 877,
#              '大': 878,
#              '傍': 879,
#              '边': 880,
#              '菜馆': 881,
#              '不错': 882,
#              '大骨棒': 883,
#              '48': 884,
#              '元': 885,
#              '5': 886,
#              '儿': 887,
#              '求': 888,
#              '分享': 889,
#              '调频': 890,
#              '内附': 891,
#              '刚': 892,
#              '有点': 893,
#              '过于': 894,
#              '合理': 895,
#              '杭州': 896,
#              '房价': 897,
#              '四五万': 898,
#              '环境': 899,
#              '好啊': 900,
#              '超级': 901,
#              '荒凉': 902,
#              '平': 903,
#              '地上': 904,
#              '盖': 905,
#              '几': 906,
#              '栋': 907,
#              '楼': 908,
#              '要价': 909,
#              '居然': 910,
#              '七万': 911,
#              '大城市': 912,
#              '性价': 913,
#              '比高': 914,
#              '虚高': 915,
#              '貌似': 916,
#              '社区': 917,
#              '平方': 918,
#              '物管费': 919,
#              '6000': 920,
#              '富豪': 921,
#              '钱多': 922,
#              '一万': 923,
#              '的说': 924,
#              '慢慢': 925,
#              '好啦': 926,
#              '皮皮': 927,
#              '活泼': 928,
#              '碰': 929,
#              '咬': 930,
#              '害怕': 931,
#              '恶补': 932,
#              '指导': 933,
#              '拜师': 934,
#              '学艺': 935,
#              '但愿': 936,
#              '找找看': 937,
#              '汇': 938,
#              '五月': 939,
#              '一定': 940,
#              '有的': 941,
#              '信心': 942,
#              '在下': 943,
#              '疏忽': 944,
#              'ok': 945,
#              '先': 946,
#              '旅途': 947,
#              '注意': 948,
#              '安全': 949,
#              '握手': 950,
#              '樓': 951,
#              '主': 952,
#              '其': 953,
#              '實': 954,
#              '追求': 955,
#              '貴': 956,
#              '學': 957,
#              '校': 958,
#              '裡': 959,
#              '賣': 960,
#              '筆': 961,
#              '大多': 962,
#              '錯': 963,
#              '試': 964,
#              '幾': 965,
#              '種': 966,
#              '總': 967,
#              '喜': 968,
#              '歡': 969,
#              '別': 970,
#              '推': 971,
#              '薦': 972,
#              '買': 973,
#              '比如': 974,
#              'bf': 975,
#              'lamy': 976,
#              '從': 977,
#              '國': 978,
#              '郵': 979,
#              '購': 980,
#              '輾': 981,
#              '轉': 982,
#              '膨润土': 983,
#              '肯定': 984,
#              '亲和力': 985,
#              '唉': 986,
#              '出生': 987,
#              '松木': 988,
#              '砂': 989,
#              '按理': 990,
#              '排斥': 991,
#              '观察': 992,
#              '再不': 993,
#              '第一次': 994,
#              '遇见': 995,
#              '金牛': 996,
#              '自我': 997,
#              '跪': 998,
#              '节奏': 999,
#              ...})

# %%
voca_file = codecs.open("./data/voca.txt","w","utf-8")
voca_file.write(str(BP.vocab))
voca_file.close()
